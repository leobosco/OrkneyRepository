# %% [markdown]
# # These are the chosen transects:
#
# T1 is the bottom transect and T2 is the top transect

# %% [markdown]
# <img src="transects.png">

# %% [markdown]
# ## Transect 1 (South):

# %% [markdown]
# ### Salinity:

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('sMwJC3uWltY')

# %% [markdown]
# ### Temperature:

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('a8bmbYnehsQ')

# %% [markdown]
# ### Density:

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('bYw3cCHz5xc')

# %% [markdown]
# ### Transport:

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('yL47MK9VI-U')

# %% [markdown]
# ## Transect 2 (North):

# %% [markdown]
# ### Salinity:

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('-1Pggm4qQoM')

# %% [markdown]
# ### Temperature:

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('SriuyOwl52U')

# %% [markdown]
# ### Density:

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('3wcnhS5jvj0')

# %% [markdown]
# ### Transport:

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('2i5cz9bmNEA')

# %% [markdown]
# ## Transect 3 (West)

# %% [markdown]
# ### Salinity

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('upGIilg-YI8')

# %% [markdown]
# ### Temperaure

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('Anldn_1593U')

# %% [markdown]
# ### Density

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('lze6-YjIma0')

# %% [markdown]
# ### Transport

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('h90Qcvs2FHE')

# %% [markdown]
# ## Transect 4 (East)

# %% [markdown]
# ### Salinity

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('DWixGd0xuLE')

# %% [markdown]
# ### Temperaure

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('Gt6izVrCmac')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/Gt6izVrCmac"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Density

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('rZIzgyMOn8Q')

# %% [markdown]
# ### Transport

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('FdmGrATlWDU')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/FdmGrATlWDU"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Transport vs Time

# %% [markdown]
# ## Per Layer

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('UZ8hXkuj_r4')

# %% [markdown]
# ## Sum of all layers

# %% [markdown]
# <img src="Total_Transport_from_mat_file2.png">
